# %% [markdown]
# <a href="https://colab.research.google.com/github/ahzam54/HACKRANK-CHALANGE/blob/main/Finding%20the%20percentage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Configure Git and Push to GitHub
# Replace the placeholders with your details. It is highly recommended to store your GitHub token in Colab's **Secrets** (the key icon on the left) for security.

# %%
import os
from google.colab import userdata

# Configuration
GITHUB_USER = 'your_username'
GITHUB_REPO = 'your_repo_name'
GITHUB_EMAIL = 'your_email@example.com'

# Retrieve token from Colab Secrets
try:
    GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
except:
    print("Please add a secret named 'GITHUB_TOKEN' in the left panel.")

# Configure user identity
# !git config --global user.email "{GITHUB_EMAIL}"
# !git config --global user.name "{GITHUB_USER}"

# Clone the repo (if not already present)
repo_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"
# !git clone {repo_url}

# After making changes inside the repo folder:
# %cd {GITHUB_REPO}
# !git add .
# !git commit -m "Commit message from Colab"
# !git push origin main

# %% [markdown]
# <a href="https://colab.research.google.com/github/ahzam54/HACKRANK-CHALANGE/blob/main/Finding%20the%20percentage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if __name__ == '__main__':
    n = int(input())
    student_marks = {}

    # Read n lines of student data
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores

    # Read the query name
    query_name = input()

    # Calculate the average for the query name
    if query_name in student_marks:
        scores = student_marks[query_name]
        average = sum(scores) / len(scores)

        # Print formatted to 2 decimal places
        print(f"{average:.2f}")
